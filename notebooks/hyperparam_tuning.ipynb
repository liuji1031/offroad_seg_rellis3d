# %%
import sys
sys.path.append('/home/ji-liu/GitHub/off_road_nav/')

from offroad_det_seg_rellis.train.hyperparam_tuning import generate_hpt_split
from offroad_det_seg_rellis.train.train import train, CONFIG_DIR

# %%
generate_hpt_split(input_file=CONFIG_DIR / "split_list_train.lst", output_file=CONFIG_DIR / "split_list_train_hpt.lst", step=3)
# Out:
# Generated subset: 3366 samples (from 10097 total)
# Output file: /home/ji-liu/GitHub/off_road_nav/offroad_det_seg_rellis/config/split_list_train_hpt.lst
# PosixPath('/home/ji-liu/GitHub/off_road_nav/offroad_det_seg_rellis/config/split_list_train_hpt.lst')

# %%
generate_hpt_split(input_file=CONFIG_DIR / "split_list_val.lst", output_file=CONFIG_DIR / "split_list_val_hpt.lst", step=2)
# Out:
# Generated subset: 1080 samples (from 2159 total)
# Output file: /home/ji-liu/GitHub/off_road_nav/offroad_det_seg_rellis/config/split_list_val_hpt.lst
# PosixPath('/home/ji-liu/GitHub/off_road_nav/offroad_det_seg_rellis/config/split_list_val_hpt.lst')
