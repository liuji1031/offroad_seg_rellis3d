# %%
import sys
sys.path.append("/home/ji-liu/GitHub/off_road_nav/")

# %%
from offroad_det_seg_rellis.dataset import create_rellis_dataloader

train_dataloader = create_rellis_dataloader(
    data_root="/home/ji-liu/GitHub/off_road_nav/RELLIS/Rellis-3D",
    list_file_path="/home/ji-liu/GitHub/off_road_nav/offroad_det_seg_rellis/train/train.lst",
    batch_size=4,
    mode="train",
    num_workers=16,
    cache_dir="/home/ji-liu/GitHub/off_road_nav/RELLIS/cache"
)

# %%
sample = next(iter(train_dataloader))

# %%
sample["images"].shape
# Out:
# torch.Size([4, 1, 3, 400, 640])

# %%
len(train_dataloader)
# Out:
# 1788
